# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None

# %%
if 'gender' in df.columns:
    from sklearn.preprocessing import LabelEncoder
    label_encoder = LabelEncoder()
    df['gender_encoded'] = label_encoder.fit_transform(df['gender'])

# %%
df = df.replace('?', np.nan)

# %%
df = df.dropna()

# %%
if 'some_numeric_column' in df.columns:
    df['some_numeric_column'] = pd.to_numeric(df['some_numeric_column'], errors='coerce')

# %%
numeric_df = df.select_dtypes(include=[np.number])

# %%
corelation = numeric_df.corr()

# %%
print(corelation)
# Out:
#                 math score  reading score  writing score  gender_encoded
# math score        1.000000       0.817580       0.802642        0.167982
# reading score     0.817580       1.000000       0.954598       -0.244313
# writing score     0.802642       0.954598       1.000000       -0.301225
# gender_encoded    0.167982      -0.244313      -0.301225        1.000000

# %%
sns.heatmap(correlation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns.relplot(x='math score', y='reading score', hue='gender', data=df)

# %%
sns.distplot(df['reading score'])
# Out:
# C:\Users\MHN-172\AppData\Local\Temp\ipykernel_1952\232294105.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['reading score'])
# <Axes: xlabel='reading score', ylabel='Density'>

# %%
sns.distplot(df['math score'])
# Out:
# C:\Users\MHN-172\AppData\Local\Temp\ipykernel_1952\2354272343.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['math score'])
# <Axes: xlabel='math score', ylabel='Density'>

# %%
sns.distplot(df['writing score'], bins=5)
# Out:
# C:\Users\MHN-172\AppData\Local\Temp\ipykernel_1952\525170827.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['writing score'], bins=5)
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
sns.catplot(x='gender', )
